# %%
import random
import numpy as np
import pandas as pd

# %%
liste = []
liste_centroïde = []
k = 3

def centroïde_aléatoire(liste,k):
    count=0
    while count != k:
        centroïde = random.choice(liste)
        count += 1
        liste_centroïde.append(centroïde)
        return liste_centroïde

# %%
centroïde_aléatoire(df_list, 3)
# Out:
# [[1.7500460089307042, 0.3346349366454223]]

# %%
liste_centroïde = []
liste = []

def calcul_distance_euclid(liste_centroïde, liste):
    for centroïde in liste_centroïde:
        for point in liste:
            dist = distance.euclidean(centroïde[i], point[i])
    return dist

# %%
cluster = []
liste = []

def affectation_des_points(cluster, point):
    classification = min(cluster)
    classification.append(point)

# %%
def centre_de_gravité():
    pass

# %%
df = pd.read_csv('C:/Users/Al_Ce/Desktop/IA/data/exos/dataset_1.csv')

# %%
df = df.drop(['Unnamed: 0'], axis = 1)

# %%
df
# Out:
#      normalized_age  normalized_salary
# 0          0.680267          -0.016342
# 1          3.809518           0.798483
# 2         -1.661372          -0.577667
# 3         -0.257307          -0.155552
# 4          0.698017           0.174561
# ..              ...                ...
# 995       -5.060165           2.482045
# 996       -5.079404           2.773580
# 997       -5.861520           3.068426
# 998       -5.018934           3.110904
# 999       -6.799331           2.082321
#
# [1000 rows x 2 columns]

# %%
df_list = df.values.tolist()
print (df_list)
# Out:
# [[0.6802672542242796, -0.01634235124987707], [3.809518438642478, 0.7984834812700092], [-1.6613723957898987, -0.5776669509655612], [-0.2573072541060864, -0.15555172507163811], [0.6980174532952329, 0.17456128595470471], [2.4722649618370576, 0.5673050456691022], [0.2068475280378083, -0.027433765917567986], [0.5672463565362535, 0.08908340767516418], [-0.34876904840186146, -0.23147121282208094], [-1.4519627568129319, -0.3729450658857801], [1.1111516122486131, 0.5167464197595522], [-1.2616805346909512, -0.38330962804852736], [-2.4724216468179, -0.8087217322382667], [-0.3182125450439171, -0.07944939174047805], [2.4979099088304846, 0.43446558652426825], [0.6428762833236951, 0.1357702652711778], [-3.367353995980676, -0.7035400125265595], [0.2657932474767661, 0.09733080257420727], [2.0440457429334997, 0.35792287144099244], [-0.5139146759780705, -0.08218841848933901], [-2.4140304932042578, -0.4631518783648809], [3.3163181718940424, 0.9509371771552172], [-0.7447263127390168, -0.1242645024693092]
# ...
